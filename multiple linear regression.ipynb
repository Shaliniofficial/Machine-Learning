# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\shalini maurya\Downloads\multiple_linear_regression.csv")
dataset.head()
# Out:
#    Experience  Age  Education  Salary
# 0           1   22         12   25000
# 1           3   25         14   40000
# 2           5   28         16   55000
# 3           7   30         16   65000
# 4           9   34         18   75000

# %%
dataset.shape
# Out:
# (10, 4)

# %%
dataset.isnull().sum()
# Out:
# Experience    0
# Age           0
# Education     0
# Salary        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Salary"]

# %%
dataset.shape
# Out:
# (10, 4)

# %%
x.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 99.30716788435942

# %%
#equation of this dataset
#y=m1x1 + m2x2 + m3x3 + c

# %%
lr.coef_
# Out:
# array([ 5574.31121459, -1352.34769111,  3668.99495537])

# %%
lr.intercept_
# Out:
# np.float64(6193.247962747235)

# %%
x.columns
# Out:
# Index(['Experience', 'Age', 'Education'], dtype='object')

# %%
#y=Experience*age + age*education + education*experience + intercept

# %%
#y=5574.31121459*Age +-1352.34769111* Education +3668.99495537*experience +6193.247962747235

# %%
lr.predict(x_test)
#put these values in upper multiple linier equation
# Out:
# array([110611.1757858 ,  40473.41870392])
